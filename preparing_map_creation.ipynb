# %% [markdown]
# To create the interactive map with busyness information for each station, we need to create a dataframe with columns of the station coordinates, and the busyness for the next 5 days.
#
# First, we do the required imports and load the coordinate csv file.

# %%
import pandas as pd
import numpy as np 

station_coordinates = pd.read_csv("./data/HSL/city_bike_station_coordinates.csv")
display(station_coordinates)
# Out:
#      FID   ID            Nimi                       Namn  \
# 0      1  501       Hanasaari                 Hanaholmen
# 1      2  503      Keilalahti                 Kägelviken
# 2      3  505  Westendinasema           Westendstationen
# 3      4  507       Golfpolku                 Golfstigen
# 4      5  509   Revontulentie             Norrskensvägen
# ..   ...  ...             ...                        ...
# 452  453  401  Koivusaari (M)  Björkholmens metrostation
# 453  454  402    Bermudankuja             Bermudagränden
# 454  455  403     Verkkosaari                  Nätholmen
# 455  456  404      Sompasaari                    Sumparn
# 456  457  405          Jollas                     Jollas
#
#                          Name                Osoite               Adress  \
# 0                   Hanasaari     Hanasaarenranta 1  Hanaholmsstranden 1
# 1                  Keilalahti      Keilalahdentie 2     Kägelviksvägen 2
# ...

# %% [markdown]
# Next, we only need to retain the station names and coordinates (x and y columns).

# %% [markdown]
# station_coordinates.drop()
